# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from openai) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: aiohttp in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from openai) (3.10.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from requests>=2.20->openai) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from requests>=2.20->openai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from requests>=2.20->openai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from requests>=2.20->openai) (2024.12.14)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from aiohttp->openai) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from aiohttp->openai) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from aiohttp->openai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from aiohttp->openai) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from aiohttp->openai) (1.15.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from aiohttp->openai) (5.0.1)
# Requirement already satisfied: colorama in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from tqdm->openai) (0.4.6)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from multidict<7.0,>=4.5->aiohttp->openai) (4.11.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\gganj\anaconda3\envs\pinsage\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp->openai) (0.2.0)

# %%
import openai
import pandas as pd
import numpy as np
import os

# OpenAI API 키 설정
os.environ['OPENAI_API_KEY'] = ""
openai.api_key = os.environ['OPENAI_API_KEY']

# CSV 파일 경로
file_path = "lecture_embedding.csv"

# 데이터 읽기
df = pd.read_csv(file_path)

# 임베딩 생성 함수
def get_openai_embedding(text):
    """OpenAI API를 사용해 텍스트 임베딩 생성"""
    try:
        response = openai.Embedding.create(
            model="text-embedding-ada-002",  # 최신 임베딩 모델
            input=text
        )
        return response['data'][0]['embedding']  # 새로운 방식으로 임베딩 반환
    except Exception as e:
        print(f"임베딩 생성 오류: {e}")
        return None

# 결과 저장 딕셔너리
embedding_results = {
    "ids": [],
    "embeddings": []
}

# 데이터프레임 순회하며 임베딩 생성
for index, row in df.iterrows():
    mcode = row['mcode']  # ID 컬럼
    l_title = str(row['l_title']).strip()  # 제목 컬럼
    u_title = str(row['u_title']).strip()  # 부제목 컬럼

    # 두 컬럼의 텍스트 결합
    combined_text = f"{l_title} {u_title}"

    # 현재 처리 중인 텍스트 출력
    print(f"Processing index {index}: {combined_text}")

    # 임베딩 생성
    embedding = get_openai_embedding(combined_text)
    if embedding:
        embedding_results["ids"].append(mcode)
        embedding_results["embeddings"].append(embedding)
        print(f"Embedding for index {index} generated successfully.")
    else:
        print(f"Embedding for index {index} failed.")

# 결과 저장
output_file = "lecture_embeddings_openai.npy"
np.save(output_file, embedding_results)
print(f"임베딩 결과가 {output_file}에 저장되었습니다.")
# Out:
# Processing index 0: ['1, 2, 3, 4, 5 알아보기'] ['1. 9까지의 수']
# Embedding for index 0 generated successfully.
# Processing index 1: ['6, 7, 8, 9 알아보기'] ['1. 9까지의 수']
# Embedding for index 1 generated successfully.
# Processing index 2: ['순서 알아보기/수의 순서 알아보기'] ['1. 9까지의 수']
# Embedding for index 2 generated successfully.
# Processing index 3: ['1만큼 더 큰 수와 1만큼 더 작은 수/수의 크기 비교하기'] ['1. 9까지의 수']
# Embedding for index 3 generated successfully.
# Processing index 4: ['1, 2, 3, 4, 5를 알아볼까요'] ['1. 9까지의 수']
# Embedding for index 4 generated successfully.
# Processing index 5: ['6, 7, 8, 9를 알아볼까요'] ['1. 9까지의 수']
# Embedding for index 5 generated successfully.
# Processing index 6: ['순서를 알아볼까요'] ['1. 9까지의 수']
# Embedding for index 6 generated successfully.
# Processing index 7: ['수의 순서를 알아볼까요'] ['1. 9까지의 수']
# Embedding for index 7 generated successfully.
# Processing index 8: ['1만큼 더 큰 수와 1만큼 더 작은 수를 알아볼까요'] ['1. 9까지의 수']
# Embedding for index 8 generated successfully.
# Processing index 9: ['수의 크기를 비교해 볼까요'] ['1. 9까지의 수']
# Embedding for index 9 generated successfully.
# Processing index 10: ['1. 9까지의 수'] ['1. 9까지의 수']
# Embedding for index 10 generated successfully.
# Processing index 11: ['여러 가지 모양 찾아보기'] ['2. 여러 가지 모양']
# Embedding for index 11 generated successfully.
# Processing index 12: ['여러 가지 모양 알아보기'] ['2. 여러 가지 모양']
# Embedding for index 12 generated successfully.
# Processing index 13: ['여러 가지 모양으로 만들어 보기'] ['2. 여러 가지 모양']
# Embedding for index 13 generated successfully.
# Processing index 14: ['모양 찾기 놀이를 해 볼까요'] ['2. 여러 가지 모양']
# Embedding for index 14 generated successfully.
# Processing index 15: ['모으기와 가르기(1)'] ['3. 덧셈과 뺄셈']
# Embedding for index 15 generated successfully.
# Processing index 16: ['모으기와 가르기(2)'] ['3. 덧셈과 뺄셈']
# Embedding for index 16 generated successfully.
# Processing index 17: ['덧셈 알아보기/덧셈하기(1)'] ['3. 덧셈과 뺄셈']
# Embedding for index 17 generated successfully.
# Processing index 18: ['덧셈하기(2)'] ['3. 덧셈과 뺄셈']
# Embedding for index 18 generated successfully.
# Processing index 19: ['뺄셈 알아보기/뺄셈하기(1)'] ['3. 덧셈과 뺄셈']
# Embedding for index 19 generated successfully.
# Processing index 20: ['뺄셈하기(2)'] ['3. 덧셈과 뺄셈']
# Embedding for index 20 generated successfully.
# Processing index 21: ['0이 있는 덧셈과 뺄셈'] ['3. 덧셈과 뺄셈']
# Embedding for index 21 generated successfully.
# Processing index 22: ['덧셈과 뺄셈하기'] ['3. 덧셈과 뺄셈']
# Embedding for index 22 generated successfully.
# Processing index 23: ['어느 것이 더 긴지 알아보기'] ['4. 비교하기']
# Embedding for index 23 generated successfully.
# Processing index 24: ['어느 것이 더 무거운지 알아보기'] ['4. 비교하기']
# Embedding for index 24 generated successfully.
# Processing index 25: ['어느 것이 더 넓은지 알아보기'] ['4. 비교하기']
# Embedding for index 25 generated successfully.
# Processing index 26: ['어느 것에 더 많이 담을 수 있는지 알아보기'] ['4. 비교하기']
# Embedding for index 26 generated successfully.
# Processing index 27: ['9 다음 수 알아보기/십몇 알아보기'] ['5. 50까지의 수']
# Embedding for index 27 generated successfully.
# Processing index 28: ['모으기와 가르기'] ['5. 50까지의 수']
# Embedding for index 28 generated successfully.
# Processing index 29: ['10개씩 묶어 세기/50까지의 수 세기'] ['5. 50까지의 수']
# Embedding for index 29 generated successfully.
# Processing index 30: ['50까지의 수의 순서 알아보기'] ['5. 50까지의 수']
# Embedding for index 30 generated successfully.
# Processing index 31: ['수의 크기 비교하기'] ['5. 50까지의 수']
# Embedding for index 31 generated successfully.
# Processing index 32: ['백 알아보기/몇백 알아보기'] ['1. 세 자리 수']
# Embedding for index 32 generated successfully.
# Processing index 33: ['세 자리 수/각 자리의 숫자가 나타내는 값 알아보기'] ['1. 세 자리 수']
# Embedding for index 33 generated successfully.
# Processing index 34: ['뛰어 세기'] ['1. 세 자리 수']
# Embedding for index 34 generated successfully.
# Processing index 35: ['수의 크기 비교하기'] ['1. 세 자리 수']
# Embedding for index 35 generated successfully.
# Processing index 36: ['백을 알아볼까요'] ['1. 세 자리 수']
# Embedding for index 36 generated successfully.
# Processing index 37: ['몇백을 알아볼까요'] ['1. 세 자리 수']
# Embedding for index 37 generated successfully.
# Processing index 38: ['세 자리 수를 알아볼까요'] ['1. 세 자리 수']
# Embedding for index 38 generated successfully.
# Processing index 39: ['각 자리의 숫자는 얼마를 나타낼까요'] ['1. 세 자리 수']
# Embedding for index 39 generated successfully.
# Processing index 40: ['뛰어 세어 볼까요'] ['1. 세 자리 수']
# Embedding for index 40 generated successfully.
# Processing index 41: ['수의 크기를 비교해 볼까요'] ['1. 세 자리 수']
# Embedding for index 41 generated successfully.
# Processing index 42: ['○과 △ 알아보기'] ['2. 여러 가지 도형']
# Embedding for index 42 generated successfully.
# Processing index 43: ['□ 알아보기'] ['2. 여러 가지 도형']
# Embedding for index 43 generated successfully.
# Processing index 44: ['칠교판으로 모양 만들기'] ['2. 여러 가지 도형']
# Embedding for index 44 generated successfully.
# Processing index 45: ['쌓은 모양 알아보기/여러 가지 모양으로 쌓기'] ['2. 여러 가지 도형']
# Embedding for index 45 generated successfully.
# Processing index 46: ['여러 가지 방법으로 덧셈해 보기(1)'] ['3. 덧셈과 뺄셈']
# Embedding for index 46 generated successfully.
# Processing index 47: ['여러 가지 방법으로 덧셈해 보기(2)'] ['3. 덧셈과 뺄셈']
# Embedding for index 47 generated successfully.
# Processing index 48: ['덧셈하기'] ['3. 덧셈과 뺄셈']
# Embedding for index 48 generated successfully.
# Processing index 49: ['여러 가지 방법으로 뺄셈해 보기(1)'] ['3. 덧셈과 뺄셈']
# Embedding for index 49 generated successfully.
# Processing index 50: ['여러 가지 방법으로 뺄셈해 보기(2)'] ['3. 덧셈과 뺄셈']
# Embedding for index 50 generated successfully.
# Processing index 51: ['뺄셈하기'] ['3. 덧셈과 뺄셈']
# Embedding for index 51 generated successfully.
# Processing index 52: ['덧셈과 뺄셈의 관계/□가 사용된 식을 만들고 □의 값 구하기'] ['3. 덧셈과 뺄셈']
# Embedding for index 52 generated successfully.
# Processing index 53: ['여러 가지 단위로 길이 재기/1cm 알아보기'] ['4. 길이 재기']
# Embedding for index 53 generated successfully.
# Processing index 54: ['자로 길이 재기/길이 어림하기'] ['4. 길이 재기']
# Embedding for index 54 generated successfully.
# Processing index 55: ['분류하는 방법 알아보기/ 기준에 따라 분류하기'] ['5. 분류하기']
# Embedding for index 55 generated successfully.
# Processing index 56: ['분류하고 세어 보기/분류한 결과 말해 보기'] ['5. 분류하기']
# Embedding for index 56 generated successfully.
# Processing index 57: ['여러 가지 방법으로 세어 보기/묶어 세기'] ['6. 곱셈']
# Embedding for index 57 generated successfully.
# Processing index 58: ['몇의 몇 배 알아보기'] ['6. 곱셈']
# Embedding for index 58 generated successfully.
# Processing index 59: ['곱셈식 알아보기/ 곱셈식으로 나타내기'] ['6. 곱셈']
# Embedding for index 59 generated successfully.
# 임베딩 결과가 lecture_embeddings_openai.npy에 저장되었습니다.

# %%
import numpy as np

# 저장된 파일 로드
embeddings = np.load('lecture_embeddings_openai.npy', allow_pickle=True)

# 데이터 내용 출력
print(f"데이터 타입: {type(embeddings)}")
print(f"데이터 내용: {embeddings}")
# Out:
# 데이터 타입: <class 'numpy.ndarray'>
# 데이터 내용: {'ids': ['T1ME11U01001', 'T1ME11U01002', 'T1ME11U01003', 'T1ME11U01004', 'T1ME11U01006', 'T1ME11U01007', 'T1ME11U01008', 'T1ME11U01009', 'T1ME11U01010', 'T1ME11U01012', 'T1ME11U01064', 'T1ME11U02001', 'T1ME11U02002', 'T1ME11U02003', 'T1ME11U02008', 'T1ME11U03001', 'T1ME11U03002', 'T1ME11U03003', 'T1ME11U03004', 'T1ME11U03005', 'T1ME11U03006', 'T1ME11U03007', 'T1ME11U03008', 'T1ME11U04001', 'T1ME11U04002', 'T1ME11U04003', 'T1ME11U04004', 'T1ME11U05001', 'T1ME11U05002', 'T1ME11U05003', 'T1ME11U05004', 'T1ME11U05005', 'T1ME21U01001', 'T1ME21U01002', 'T1ME21U01003', 'T1ME21U01004', 'T1ME21U01006', 'T1ME21U01007', 'T1ME21U01008', 'T1ME21U01009', 'T1ME21U01010', 'T1ME21U01011', 'T1ME21U02001', 'T1ME21U02002', 'T1ME21U02003', 'T1ME21U02004', 'T1ME21U03001', 'T1ME21U03002', 'T1ME21U03003', 'T1ME21U03004', 'T1ME21U03005', 'T1ME21U03006', 'T1ME21U03007', 'T1ME21U04001', 'T1ME21U04002', 'T1ME21U05001', 'T1ME21U05002', 'T1ME21U06001', 'T1ME21U06002', 'T1ME21U06003'], 'embeddings': [[-0.018198207020759583, -0.011859506368637085, 0.016270307824015617, -0.023310063406825066, -0.01911834254860878, 0.026990599930286407, -0.026596257463097572, -0.01821281388401985, -0.030437450855970383, -0.0018010163912549615, -4.227550743962638e-05, 0.020856373012065887, -0.04267669469118118, 0.002548625459894538, -0.0012314096093177795, 0.01672307215631008, 0.003706095740199089, -0.016328729689121246, -0.012845364399254322, -0.020856373012065887, -0.009800158441066742, 0.003231423208490014, -0.004808796104043722, -0.007189460564404726, -0.017205046489834785, 0.0038083328399807215, -0.005137415137141943, -0.02208321914076805, -0.010070356540381908, 0.002440911252051592, 0.03233614191412926, -0.026377176865935326, -0.0053857057355344296, -0.022638220340013504, -0.0037280037067830563, 0.013414970599114895, -0.007740810513496399, -0.005078994203358889, 0.03245298191905022, -0.008215483278036118, 0.005827515851706266, -0.010413581505417824, 0.014765961095690727, -0.006331399083137512, 0.01294029876589775, 0.01770162768661976, 0.011939835734665394, -0.026274939998984337, 0.0010013760766014457, 0.04066116362810135, 0.005831167101860046, 0.0031072781421244144, -0.01920597441494465, -0.030408240854740143, -0.007269789464771748, 0.007550941780209541, 0.006616202183067799, -0.0032186436001211405, -0.017234258353710175, -0.003678710665553808, 0.0003509836969897151, 0.004231886472553015, -0.022010192275047302, 0.006608899682760239, -0.015817543491721153, -0.005360146053135395, -0.01606583409011364, 0.00875587947666645, 0.010428186506032944, -0.007864955812692642, 0.017467942088842392, 0.03960958123207092, -0.0019224230200052261, -0.014641816727817059, 0.033913515508174896, -0.004082182422280312, 0.0022291343193501234, -0.004056622739881277, 0.0030506826005876064, 0.009288973174989223, 0.013604840263724327, 0.008273904211819172, 0.0012916565174236894, -0.008098640479147434, 0.01184490043669939, 0.017949918285012245, -0.016343334689736366, 0.04697065427899361, -0.0059334044344723225, -0.01152358390390873, 0.016533203423023224, 0.0133638521656394, 0.008500286377966404, 0.031196927651762962, 9.442100417800248e-05, 0.018183602020144463, -0.022740457206964493, 0.0004568721342366189, -0.018110575154423714, -0.006649064365774393, -0.014539578929543495, -0.004951197654008865, -0.023938091471791267, 0.0018311399035155773, -0.03461456671357155, -0.034702200442552567, 0.012699310667812824, -0.013882340863347054, 0.013006022199988365, -0.0039689913392066956, -0.006236464250832796, 0.02688836306333542, 0.010566936805844307, -0.030174557119607925, 0.008580615743994713, 0.009354696609079838, 0.008982261642813683, -0.015671489760279655, -0.019614921882748604, -0.011180359870195389, 0.018694788217544556, 0.04492591321468353, 0.008492983877658844, -0.034030355513095856, 0.005666857585310936, 0.002603395376354456, 0.011253385804593563, -0.03604588657617569, -0.027983760461211205, -0.03879168629646301, 0.10959819704294205, 0.023178616538643837, 0.03844115883111954, 0.0082812067121267 ...

# %%
import numpy as np

# 저장된 .npy 파일 불러오기
file_path = "lecture_embeddings_openai.npy"  # 저장된 파일 경로
embedding_dict = np.load(file_path, allow_pickle=True).item()  # 딕셔너리로 로드

# 전체 데이터 확인
print(f"총 임베딩 개수: {len(embedding_dict)}")

# 특정 인덱스의 임베딩 가져오기
index = 'T1ME11U03006'  # 확인하려는 인덱스
embedding = embedding_dict.get(index, None)

if embedding is not None:
    print(f"Index {index}의 임베딩 크기: {embedding.shape}")
    print(f"Index {index}의 임베딩 값:\n{embedding}")
else:
    print(f"Index {index}에 해당하는 임베딩이 없습니다.")
# Out:
# 총 임베딩 개수: 2
# Index T1ME11U03006에 해당하는 임베딩이 없습니다.

# %%
import numpy as np

# 저장된 파일 로드
file_path = "lecture_embeddings_openai.npy"
data = np.load(file_path, allow_pickle=True)

# 딕셔너리로 변환
data_dict = data.item()

# ids와 embeddings 분리
ids = data_dict['ids']
embeddings = data_dict['embeddings']

# 데이터 확인
print(f"총 ID 개수: {len(ids)}")
print(f"임베딩 개수: {len(embeddings)}")
print(f"임베딩 차원: {len(embeddings[0]) if embeddings else 'No embeddings available'}")

# 특정 ID의 임베딩 확인
target_id = "T1ME11U01002"  # 원하는 ID
if target_id in ids:
    index = ids.index(target_id)  # ID에 해당하는 인덱스
    print(f"ID {target_id}의 임베딩:\n{embeddings[index]}")
else:
    print(f"ID {target_id}에 해당하는 임베딩이 없습니다.")
# Out:
# 총 ID 개수: 60
# 임베딩 개수: 60
# 임베딩 차원: 1536
# ID T1ME11U01002의 임베딩:
# [-0.011153735220432281, -0.02023845538496971, 0.019903333857655525, -0.021884925663471222, -0.021229250356554985, 0.019801339134573936, -0.03278367593884468, -0.01607128605246544, -0.03596004843711853, 0.001192050869576633, -0.008545611053705215, 0.013026047497987747, -0.03520238399505615, -0.0018440817948430777, 0.007999217137694359, 0.024755317717790604, 0.006287180352956057, -0.014126121066510677, -0.01436653546988964, -0.011547138914465904, -0.01709122210741043, 0.007372684311121702, -0.005121538415551186, -0.00105089892167598, -0.016085857525467873, 0.006982923019677401, 0.0036790568847209215, -0.01894167996942997, -0.010308644734323025, 0.002708295825868845, 0.03141404688358307, -0.017353491857647896, -0.006505738478153944, -0.0264163576066494, -0.010753045789897442, 0.019553640857338905, -0.007296189200133085, -0.003668128978461027, 0.026226939633488655, -0.0030270260758697987, 0.010636481456458569, -0.008013787679374218, -0.004276448395103216, -0.011175590567290783, 0.01859198696911335, 0.019655635580420494, 0.002599016996100545, -0.02659120410680771, 0.00758395716547966, 0.038116488605737686, 0.00803564302623272, -0.011663703247904778, -0.023021426051855087, -0.03240484371781349, -0.010060945525765419, -9.937551658367738e-05, -0.0006228898419067264, -0.003671771613880992, -0.006141475401818752, -0.0005127002368681133, 0.009266852401196957, 0.009878814220428467, -0.024784458801150322, 0.007237907033413649, -0.01901453174650669, -0.004389369860291481, -0.010177509859204292, 0.002631800714880228, -0.0008888018783181906, -0.003251047804951668, 0.02593553066253662, 0.04540174826979637, -0.0014415710465982556, -0.023633386939764023, 0.03141404688358307, -0.010476205497980118, 0.0035970977041870356, -0.005201676394790411, 0.0011583565501496196, 0.014293682761490345, 0.01207167748361826, 0.006148760672658682, -0.00082687713438645, -0.004964905325323343, 0.008939015679061413, 0.012042536400258541, -0.014293682761490345, 0.0342407263815403, 0.0008842485840432346, -0.009682112373411655, 0.007339900825172663, 0.015969293192029, 0.007303474470973015, 0.02373538166284561, -0.015022208914160728, 0.026095805689692497, -0.026576632633805275, 0.00603583874180913, -0.01607128605246544, -0.00092704949202016, -0.013521444983780384, -0.005114253610372543, -0.02369166910648346, -0.0036517372354865074, -0.026678627356886864, -0.038320474326610565, -0.002629979280754924, -0.02054443582892418, 0.0171640757471323, -0.013506874442100525, -0.006316321436315775, 0.028543652966618538, 0.0203404501080513, -0.02149152010679245, 0.0027429007459431887, 0.004709921311587095, 0.011153735220432281, -0.00582820875570178, -0.0212146807461977, -0.022875720635056496, 0.01936422474682331, 0.03561035543680191, 0.00017996871611103415, -0.024697035551071167, 0.007347186096012592, -0.003384003881365061, 0.003689984790980816, -0.029651014134287834, -0.0272905882447958, -0.04088488593697548, 0.09494152665138245, 0.023895656690001488, 0.0406809002161026, 0.007066703401505947, 0.010053660720586777, -0.010549058206379414, -0.007267048116773367, 0.01747005619108677, -0.03697998449206352, -0.012953194789588451, 0.012975050136446953, -0.003232834627851844, 0.007940934970974922, -0.030102699995040894, 0.031180918216705322, 0.009536406956613064, 0.0464799664914608, -0.004582429304718971, -0.0018668482080101967, -0.03228827938437462, 0.03596004843711853, -0.02436191402375698, 0.003995965700596571, 0.02481359988451004, 0.002553484169766307, -0.022496886551380157, 0.012749207206070423, -0.004006893839687109, -0.007729662116616964, 0.0100318044424057, -0.0359891913831234, -0.0024041361175477505, 0.014373820275068283, -0.013339313678443432, 0.011700129136443138, 0.024157926440238953, -0.0027702206280082464, -0.01526990719139576, -0.013477733358740807, -0.015634169802069664, -0.009580118581652641, -0.01167098805308342, -0.004207238554954529, -0.003977752756327391, -0.016231562942266464, -0.004199953284114599, 0.0152553366497159, -0.015517606399953365, -0.01614413969218731, 0.0085 ...

# %%
import numpy as np
from sklearn.decomposition import PCA

# 1. 임베딩 데이터 로드
file_path = "lecture_embeddings_openai.npy"
data = np.load(file_path, allow_pickle=True).item()

# 2. 임베딩 데이터 추출
embeddings = np.array(data['embeddings'])  # 임베딩 배열
print(f"임베딩 shape: {embeddings.shape}")

# 3. PCA 수행
pca = PCA()
pca.fit(embeddings)

# 4. 설명 분산 비율 계산
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance_ratio)

# 5. 90% 이상의 누적 분산을 설명하는 최소 차원 수 계산
optimal_dimension_90 = np.argmax(cumulative_variance >= 0.9) + 1

# 결과 출력
print(f"누적 분산: {cumulative_variance}")
print(f"90% 이상의 누적 분산을 설명하는 차원 수: {optimal_dimension_90}")
# Out:
# 임베딩 shape: (60, 1536)
# 누적 분산: [0.18768156 0.33489173 0.42774121 0.48989782 0.53872973 0.58394079
#  0.62089452 0.65414009 0.6864327  0.71567995 0.74002044 0.76091274
#  0.7788387  0.79559183 0.81127477 0.82586709 0.83957769 0.85172003
#  0.86300317 0.87342615 0.88306397 0.89226097 0.90007657 0.90773041
#  0.91476728 0.92108599 0.92721616 0.93302301 0.93868172 0.94410099
#  0.94913444 0.95388169 0.95818598 0.96208492 0.96587994 0.96928426
#  0.97232067 0.9752326  0.97768061 0.98004194 0.98228336 0.98447578
#  0.98628547 0.98800966 0.98955715 0.99095224 0.99224421 0.99338245
#  0.99445868 0.99547581 0.99639421 0.99720882 0.99800202 0.99855377
#  0.99898984 0.99934017 0.99965657 0.99986916 1.         1.        ]
# 90% 이상의 누적 분산을 설명하는 차원 수: 23

# %%
from sklearn.decomposition import PCA
import numpy as np
from sklearn.preprocessing import normalize

# 1. 임베딩 딕셔너리 로드
embeddings_dict = np.load("lecture_embeddings_openai.npy", allow_pickle=True).item()

# 2. 데이터 추출
f_mchapter_ids = embeddings_dict['ids']  # 키: ID 리스트
embeddings = np.array(embeddings_dict['embeddings'])  # 값: 임베딩 배열
print(f"원본 임베딩 shape: {embeddings.shape}")

# 3. 정규화 (L2 정규화)
normalized_embeddings = normalize(embeddings, axis=1)  # 각 행을 정규화
print(f"정규화된 임베딩 shape: {normalized_embeddings.shape}")

# 4. PCA 적용 (23차원으로 축소)
pca = PCA(n_components=23)
final_reduced_embeddings = pca.fit_transform(normalized_embeddings)
print(f"PCA 적용 후 임베딩 shape: {final_reduced_embeddings.shape}")

# 5. 축소된 데이터 저장
output_file = "reduced_lecture_embeddings_23.npy"
np.save(output_file, {"ids": f_mchapter_ids, "embeddings": final_reduced_embeddings.tolist()})
print(f"PCA 적용 후 23차원으로 축소된 결과를 {output_file}에 저장했습니다.")

# 6. 저장된 데이터 확인
node_features = np.load(output_file, allow_pickle=True).item()
print("축소된 데이터 타입:", type(node_features))
print("데이터의 키:", node_features.keys())
print("첫 번째 중단원의 임베딩:", node_features['embeddings'][0])
# Out:
# 원본 임베딩 shape: (60, 1536)
# 정규화된 임베딩 shape: (60, 1536)
# PCA 적용 후 임베딩 shape: (60, 23)
# PCA 적용 후 23차원으로 축소된 결과를 reduced_lecture_embeddings_23.npy에 저장했습니다.
# 축소된 데이터 타입: <class 'dict'>
# 데이터의 키: dict_keys(['ids', 'embeddings'])
# 첫 번째 중단원의 임베딩: [-0.13858413606340947, -0.09395869190764769, -0.1142457569781688, 0.08082359630883164, -0.06381934058492253, -0.019941505417812755, 0.08208730571371921, 0.08218727493139667, 0.1058757105164456, 0.07834404066749626, -0.13062563050260578, -0.021516030562426527, 0.025965099444126487, -0.012143636865225894, 0.027123614807393757, -0.01704841803582545, 0.0011397782325474274, -0.020355168618992482, -0.018303428865300092, 0.046888047167228254, -0.024920956483559246, -0.005597129296978141, -0.04249061784042566]
