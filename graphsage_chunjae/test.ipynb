# %%
import matplotlib.pyplot as plt
import numpy as np
from graph_generator3 import generate_graph

graph = generate_graph()
# 중단원 노드 특성 가져오기 (예: 핵심 단어 임베딩)
concept_features = graph.ndata['feat']['concept']  # 중단원 노드 특성

# 첫 번째 특성(열)에 대한 히스토그램
plt.hist(concept_features[:, 0].numpy(), bins=30, alpha=0.7, color='blue')
plt.title("Feature Distribution (1st Dimension)")
plt.xlabel("Feature Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# Graph(num_nodes={'concept': 34, 'lecture': 60, 'student': 32946},
#       num_edges={('concept', 'teaches', 'lecture'): 68, ('student', 'understands', 'concept'): 232806},
#       metagraph=[('concept', 'lecture', 'teaches'), ('student', 'concept', 'understands')])
# Student node feature shape: torch.Size([32946, 34])
# Concept node feature shape: torch.Size([34, 6])
# Lecture node feature shape: torch.Size([60, 23])
# Edge weights for 'understands': tensor([0.2600, 0.5900, 0.8600, 0.9700, 0.1200])
# Node types: ['concept', 'lecture', 'student']
# Edge types: ['teaches', 'understands']
# Graph schema: Graph(num_nodes={'concept': 34, 'lecture': 60, 'student': 32946},
#       num_edges={('concept', 'teaches', 'lecture'): 68, ('student', 'understands', 'concept'): 232806},
#       metagraph=[('concept', 'lecture', 'teaches'), ('student', 'concept', 'understands')])
# Student features: dict_keys(['feat'])
# Concept features: dict_keys(['feat'])
# Lecture features: dict_keys(['feat'])
