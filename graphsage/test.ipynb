# %%
import numpy as np

# 임베딩 파일 로드 및 확인
embedding_file = "trained_node_embeddings.npy"

embeddings = np.load(embedding_file)
print(f"임베딩 크기: {embeddings.shape}")
print(f"임베딩 데이터 예시 (처음 5개):\n{embeddings[:5]}")

# 노드 및 엣지 개수 출력
num_nodes = embeddings.shape[0]
print(f"노드 개수: {num_nodes}")
# Out:
# 임베딩 크기: (91, 32)
# 임베딩 데이터 예시 (처음 5개):
# [[ 0.47743195 -0.0398386  -0.5151781  -0.09463854  0.29883304  0.06327515
#    0.33484522 -0.153691    0.3655578  -0.27825934 -0.37229598  0.02106458
#   -0.5094296  -0.2689848   0.54256254  0.30288318 -0.41002193  0.28533262
#    0.19346711  0.04500654  0.57651234 -0.16456167  0.25400165  0.06875055
#    0.32874548  0.26576582 -0.35245854 -0.6157688   0.06968262 -0.24800465
#   -0.2101135  -0.29399508]
#  [ 1.0928301  -0.01297078 -0.8328124  -0.40807247 -0.16113155  0.1670312
#    0.42596635 -0.817779    0.55086315 -0.9175787  -0.38292485  0.2913484
#   -0.66434056 -0.02599928  0.6794808   0.18313071 -0.3569578   0.4073565
#   -0.24968275  0.02754077  0.36773834  0.14833182  0.5929972   0.18914285
#    0.65558064  0.33609402 -0.5697343  -0.43226042  0.1327314  -0.4296826
#   -0.46816438 -0.44632658]
#  [ 0.90461946  0.22677238 -0.46142137 -0.54259694 -0.1184855  -0.05835702
# ...
